# %%
from pathlib import Path
import pandas as pd
import json

data_path = Path("data")

df = pd.read_csv(data_path / "base_data.csv")

with open(data_path / "csv_dictionary.json") as f:
    raw = json.load(f)

CSVDictionary = {
    k: pd.DataFrame(v)
    for k, v in raw.items()
}

# %%
df.head()
# Out:
#                                      id                                 url  \
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 1  36240051-018E-4915-B6EA-3F1A7F24FBE4  https://www.nps.gov/arch/index.htm
# 2  B170CCF7-7AB9-48FF-950E-31815FD4DBB2  https://www.nps.gov/badl/index.htm
# 3  C9056F71-7162-4208-8AE9-2D0AEFA594FD  https://www.nps.gov/bibe/index.htm
# 4  FBF9F793-5114-4B61-A5BA-6F9ADDFDF459  https://www.nps.gov/bisc/index.htm
#
#                  fullName parkCode  \
# 0    Acadia National Park     acad
# 1    Arches National Park     arch
# 2  Badlands National Park     badl
# 3  Big Bend National Park     bibe
# 4  Biscayne National Park     bisc
#
#                                          description   latitude   longitude  \
# 0  Acadia National Park protects the natural beau...  44.409286  -68.247501
# 1  Discover a landscape of contrasting colors, la...  38.722618 -109.586367
# 2  The rugged beauty of the Badlands draws visito...  43.685848 -102.482942
# 3  There is a place in Far West Texas where night...  29.298178 -103.229790
# 4  Within sight of Miami, yet worlds away, Biscay...  25.490587  -80.210239
#
#                               latLong  \
# 0      lat:44.409286, long:-68.247501
# 1  lat:38.72261844, long:-109.5863666
# 2   lat:43.68584846, long:-102.482942
# 3  lat:29.29817767, long:-103.2297897
# 4    lat:25.490587, long:-80.21023851
#
#                                           activities  \
# 0  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 1  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 2  [{'id': '5F723BAD-7359-48FC-98FA-631592256E35'...
# 3  [{'id': '5F723BAD-7359-48FC-98FA-631592256E35'...
# 4  [{'id': '071BA73C-1D3C-46D4-A53C-00D5602F7F0E'...
#
#                                               topics  ...  \
# 0  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 1  [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B'...  ...
# 2  [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B'...  ...
# 3  [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B'...  ...
# 4  [{'id': '28AEAE85-9DDA-45B6-981B-1CFCDCC61E14'...  ...
#
#                                       operatingHours  \
# 0  [{'exceptions': [], 'description': 'Acadia Nat...
# 1  [{'exceptions': [], 'description': 'Arches Nat...
# 2  [{'exceptions': [], 'description': 'The park i...
# 3  [{'exceptions': [], 'description': 'Big Bend N...
# 4  [{'exceptions': [], 'description': 'Launch you...
#
#                                            addresses  \
# 0  [{'postalCode': '04609', 'city': 'Bar Harbor',...
# 1  [{'postalCode': '84532', 'city': 'Moab', 'stat...
# 2  [{'postalCode': '57750', 'city': 'Interior', '...
# 3  [{'postalCode': '79834', 'city': 'Big Bend Nat...
# 4  [{'postalCode': '33033', 'city': 'Homestead', ...
#
#                                               images  \
# 0  [{'credit': 'NPS / Kristi Rugg', 'title': 'Sun...
# 1  [{'credit': 'NPS/Veronica Verdin', 'title': 'A...
# 2  [{'credit': 'NPS Photo', 'title': 'Badlands St...
# 3  [{'credit': 'NPS', 'title': 'Blooming Cenizo',...
# 4  [{'credit': 'NPS image by Shaun Wolfe', 'title...
#
#                                          weatherInfo      name    designation  \
# 0  Located on Mount Desert Island in Maine, Acadi...    Acadia  National Park
# 1  Arches is part of the Colorado Plateau, a "hig...    Arches  National Park
# 2  The Badlands weather is variable and unpredict...  Badlands  National Park
# 3  Big Bend is in the Chihuahuan Desert. Sunshine...  Big Bend  National Park
# 4  The park is situated in a subtropical climate,...  Biscayne  National Park
#
#                                           multimedia relevanceScore  \
# 0  [{'title': 'Cultural Connections in the Park',...            1.0
# 1                                                 []            1.0
# 2                                                 []            1.0
# 3                                                 []            1.0
# 4                                                 []            1.0
#
#                                contacts.phoneNumbers  \
# 0  [{'phoneNumber': '2072883338', 'description': ...
# 1  [{'phoneNumber': '4357192299', 'description': ...
# 2  [{'phoneNumber': '6054335361', 'description': ...
# 3  [{'phoneNumber': '432-477-2251', 'description'...
# 4  [{'phoneNumber': '786-335-3620', 'description'...
#
#                              contacts.emailAddresses
# 0  [{'description': '', 'emailAddress': 'acadia_i...
# 1  [{'description': '', 'emailAddress': 'archinfo...
# 2  [{'description': '', 'emailAddress': 'badl_inf...
# 3  [{'description': '', 'emailAddress': 'bibe_inf...
# 4  [{'description': "If you can't find what you a...
#
# [5 rows x 26 columns]

# %%
CSVDictionary.keys()
# Out:
# dict_keys(['ACAD', 'ARCH', 'BADL', 'BIBE', 'BISC', 'BLCA', 'BRCA', 'CANY', 'CARE', 'CAVE', 'CHIS', 'CONG', 'CRLA', 'CUVA', 'DEVA', 'DENA', 'DRTO', 'EVER', 'GAAR', 'JEFF', 'GLBA', 'GLAC', 'GRCA', 'GRTE', 'GRBA', 'GRSA', 'GRSM', 'GUMO', 'HALE', 'HAVO', 'HOSP', 'INDU', 'ISRO', 'JOTR', 'KATM', 'KEFJ', 'KOVA', 'LACL', 'LAVO', 'MACA', 'MEVE', 'MORA', 'NPSA', 'NERI', 'NOCA', 'OLYM', 'PEFO', 'PINN', 'ROMO', 'SAGU', 'SHEN', 'THRO', 'VIIS', 'VOYA', 'WHSA', 'WICA', 'WOTR', 'WRST', 'YELL', 'YOSE', 'ZION'])

# %%
print(CSVDictionary.get("ACAD", "Key not found"))
CSVDictionary["ACAD"].shape
# Out:
#      Year  RecreationVisitors TotalRecreationVisitors
# 0    1919               64000             196,625,585
# 1    1920               66500             196,625,585
# 2    1921               69836             196,625,585
# 3    1922               73779             196,625,585
# 4    1923               64200             196,625,585
# ..    ...                 ...                     ...
# 102  2021             4069098             196,625,585
# 103  2022             3970260             196,625,585
# 104  2023             3879890             196,625,585
# 105  2024             3961661             196,625,585
# 106  2025             4079318             196,625,585
#
# [107 rows x 3 columns]
# (107, 3)

# %%
#TESTING BUG

print(df.columns.tolist())
# Out:
# ['id', 'url', 'fullName', 'parkCode', 'description', 'latitude', 'longitude', 'latLong', 'activities', 'topics', 'states', 'entranceFees', 'entrancePasses', 'fees', 'directionsInfo', 'directionsUrl', 'operatingHours', 'addresses', 'images', 'weatherInfo', 'name', 'designation', 'multimedia', 'relevanceScore', 'contacts.phoneNumbers', 'contacts.emailAddresses']

# %%
import pandas as pd
import json

# Load base_data.csv
base_df = pd.read_csv(data_path/'base_data.csv')

#When was the "base_data.csv" file created?

# Load csv_dictionary.json
with open(data_path/'csv_dictionary.json', 'r') as f:
    csv_dict = json.load(f)

#Do we need this line? The csv was already loaded in the first block

# Prepare a list to collect new rows
rows = []

# For each park in the dictionary
for park_code, records in csv_dict.items():
    for record in records:
        row = base_df[base_df['parkCode'].str.lower() == park_code.lower()].copy()
        if not row.empty:
            row = row.iloc[0].to_dict()
            row['year'] = record['Year']
            row['annual visits'] = record['RecreationVisitors']
            row['total visits'] = record.get('TotalRecreationVisitors', None)
            rows.append(row)

# Create the new DataFrame
combined_df = pd.DataFrame(rows)
combined_df.head()
# Out:
#                                      id                                 url  \
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 2  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 3  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 4  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
#
#                fullName parkCode  \
# 0  Acadia National Park     acad
# 1  Acadia National Park     acad
# 2  Acadia National Park     acad
# 3  Acadia National Park     acad
# 4  Acadia National Park     acad
#
#                                          description   latitude  longitude  \
# 0  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 1  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 2  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 3  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 4  Acadia National Park protects the natural beau...  44.409286 -68.247501
#
#                           latLong  \
# 0  lat:44.409286, long:-68.247501
# 1  lat:44.409286, long:-68.247501
# 2  lat:44.409286, long:-68.247501
# 3  lat:44.409286, long:-68.247501
# 4  lat:44.409286, long:-68.247501
#
#                                           activities  \
# 0  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 1  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 2  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 3  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 4  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
#
#                                               topics  ...  \
# 0  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 1  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 2  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 3  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 4  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
#
#                                          weatherInfo    name    designation  \
# 0  Located on Mount Desert Island in Maine, Acadi...  Acadia  National Park
# 1  Located on Mount Desert Island in Maine, Acadi...  Acadia  National Park
# 2  Located on Mount Desert Island in Maine, Acadi...  Acadia  National Park
# 3  Located on Mount Desert Island in Maine, Acadi...  Acadia  National Park
# 4  Located on Mount Desert Island in Maine, Acadi...  Acadia  National Park
#
#                                           multimedia relevanceScore  \
# 0  [{'title': 'Cultural Connections in the Park',...            1.0
# 1  [{'title': 'Cultural Connections in the Park',...            1.0
# 2  [{'title': 'Cultural Connections in the Park',...            1.0
# 3  [{'title': 'Cultural Connections in the Park',...            1.0
# 4  [{'title': 'Cultural Connections in the Park',...            1.0
#
#                                contacts.phoneNumbers  \
# 0  [{'phoneNumber': '2072883338', 'description': ...
# 1  [{'phoneNumber': '2072883338', 'description': ...
# 2  [{'phoneNumber': '2072883338', 'description': ...
# 3  [{'phoneNumber': '2072883338', 'description': ...
# 4  [{'phoneNumber': '2072883338', 'description': ...
#
#                              contacts.emailAddresses  year annual visits  \
# 0  [{'description': '', 'emailAddress': 'acadia_i...  1919         64000
# 1  [{'description': '', 'emailAddress': 'acadia_i...  1920         66500
# 2  [{'description': '', 'emailAddress': 'acadia_i...  1921         69836
# 3  [{'description': '', 'emailAddress': 'acadia_i...  1922         73779
# 4  [{'description': '', 'emailAddress': 'acadia_i...  1923         64200
#
#   total visits
# 0  196,625,585
# 1  196,625,585
# 2  196,625,585
# 3  196,625,585
# 4  196,625,585
#
# [5 rows x 29 columns]

# %%
# Build a set of activities from all unique park codes in combined_df

activities = set()
import re

for code in combined_df['parkCode'].unique():
    park_rows = combined_df[combined_df['parkCode'] == code]
    for row_activities in park_rows['activities']:
        if isinstance(row_activities, str):
            matches = re.findall(r':\s*([^,;]+)', row_activities)
            for activity in matches:
                cleaned = re.sub(r'[^A-Za-z\s]', '', activity)
                cleaned = cleaned.strip()
                if cleaned and cleaned[0].isupper() and not cleaned.isupper():
                    activities.add(cleaned.lower())
print(activities)
# Out:
# {'canyoneering', 'swimming', 'birdwatching', 'boat tour', 'motorized boating', 'downhill skiing', 'gathering and foraging', 'scuba diving', 'junior ranger program', 'scenic driving', 'horse camping see also camping', 'geocaching', 'mountain climbing', 'busshuttle guided tour', 'park film', 'atv offroading', 'arts and crafts', 'wildlife watching', 'fixed wing flying', 'ice skating', 'food', 'caving', 'horse trekking', 'tubing', 'boating', 'orienteering', 'snowshoeing', 'selfguided tours  auto', 'astronomy', 'crosscountry skiing', 'reenactments', 'gift shop and souvenirs', 'skiing', 'bookstore and park store', 'craft demonstrations', 'shopping', 'first person interpretation', 'rv camping', 'picnicking', 'offtrail permitted hiking', 'dining', 'whitewater rafting', 'hunting', 'rock climbing', 'snow play', 'car or front country camping', 'backcountry hiking', 'snorkeling', 'flying', 'arts and culture', 'horse camping see also horsestock use', 'paddling', 'camping', 'backcountry camping', 'snow tubing', 'compass and gps', 'canoe or kayak camping', 'frontcountry hiking', 'playground', 'stargazing', 'freshwater swimming', 'helicopter flying', 'snowmobiling', 'dog sledding', 'handson', 'hunting and gathering', 'river tubing', 'stand up paddleboarding', 'surfing', 'water skiing', 'climbing', 'cultural demonstrations', 'kayaking', 'auto and atv', 'guided tours', 'volunteer vacation', 'golf', 'theater', 'road biking', 'fishing', 'selfguided tours  walking', 'museum exhibits', 'mountain biking', 'pool swimming', 'sailing', 'hiking', 'biking', 'saltwater fishing', 'citizen science', 'ice climbing', 'horseback riding', 'historic weapons demonstration', 'fly fishing', 'group camping', 'saltwater swimming', 'canoeing', 'auto offroading', 'live music', 'living history', 'freshwater fishing'}

# %%
# Create dummy variables for each activity in the set
for activity in activities:
    col_name = f'activity_{activity.replace(" ", "_")}'
    combined_df[col_name] = combined_df['activities'].apply(lambda x: 1 if isinstance(x, str) and activity in x.lower() else 0)
combined_df.head()
# Out:
# C:\Users\Gunnar Griffith\AppData\Local\Temp\ipykernel_2664\1166237519.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df[col_name] = combined_df['activities'].apply(lambda x: 1 if isinstance(x, str) and activity in x.lower() else 0)
# C:\Users\Gunnar Griffith\AppData\Local\Temp\ipykernel_2664\1166237519.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df[col_name] = combined_df['activities'].apply(lambda x: 1 if isinstance(x, str) and activity in x.lower() else 0)
#                                      id                                 url  \
# 0  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 2  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 3  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 4  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
#
#                fullName parkCode  \
# 0  Acadia National Park     acad
# 1  Acadia National Park     acad
# 2  Acadia National Park     acad
# 3  Acadia National Park     acad
# 4  Acadia National Park     acad
#
#                                          description   latitude  longitude  \
# 0  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 1  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 2  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 3  Acadia National Park protects the natural beau...  44.409286 -68.247501
# 4  Acadia National Park protects the natural beau...  44.409286 -68.247501
#
#                           latLong  \
# 0  lat:44.409286, long:-68.247501
# 1  lat:44.409286, long:-68.247501
# 2  lat:44.409286, long:-68.247501
# 3  lat:44.409286, long:-68.247501
# 4  lat:44.409286, long:-68.247501
#
#                                           activities  \
# 0  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 1  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 2  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 3  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 4  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
#
#                                               topics  ...  \
# 0  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 1  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 2  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 3  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 4  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
#
#   activity_horseback_riding activity_historic_weapons_demonstration  \
# 0                         1                                       0
# 1                         1                                       0
# 2                         1                                       0
# 3                         1                                       0
# 4                         1                                       0
#
#   activity_fly_fishing activity_group_camping activity_saltwater_swimming  \
# 0                    1                      1                           1
# 1                    1                      1                           1
# 2                    1                      1                           1
# 3                    1                      1                           1
# 4                    1                      1                           1
#
#   activity_canoeing activity_auto_offroading activity_live_music  \
# 0                 1                        0                   0
# 1                 1                        0                   0
# 2                 1                        0                   0
# 3                 1                        0                   0
# 4                 1                        0                   0
#
#   activity_living_history activity_freshwater_fishing
# 0                       0                           1
# 1                       0                           1
# 2                       0                           1
# 3                       0                           1
# 4                       0                           1
#
# [5 rows x 129 columns]

# %%
combined_df.columns
# Out:
# Index(['id', 'url', 'fullName', 'parkCode', 'description', 'latitude',
#        'longitude', 'latLong', 'activities', 'topics',
#        ...
#        'activity_horseback_riding', 'activity_historic_weapons_demonstration',
#        'activity_fly_fishing', 'activity_group_camping',
#        'activity_saltwater_swimming', 'activity_canoeing',
#        'activity_auto_offroading', 'activity_live_music',
#        'activity_living_history', 'activity_freshwater_fishing'],
#       dtype='str', length=129)

# %%
combined_df.to_csv(data_path/'final.csv', index=False)
